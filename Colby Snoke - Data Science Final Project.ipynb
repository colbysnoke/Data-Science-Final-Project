# %% [markdown]
# # Colby Snoke
# ## 11/28/2022

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
# %matplotlib inline
import statistics as stats
import numpy as np

# %%
#read in data 
fortnite = "all_weapons_fortnite - Sheet1.csv"
fortnite = pd.read_csv(fortnite, parse_dates=True)

# %%
#check to make sure data is in variable
fortnite
# Out:
#         Rarity                    Weapon    DPS  Damage  Fire Rate  \
# 0       Common             Assault Rifle  165.0    30.0        5.5
# 1     Uncommon             Assault Rifle  170.5    31.0        5.5
# 2         Rare             Assault Rifle  181.5    33.0        5.5
# 3         Epic             Assault Rifle  192.5    35.0        5.5
# 4    Legendary             Assault Rifle  198.0    36.0        5.5
# ..         ...                       ...    ...     ...        ...
# 264       Epic  Mechanical Shockwave Bow   89.0    89.0        1.0
# 265  Legendary  Mechanical Shockwave Bow   94.0    94.0        1.0
# 266       Epic  Mechanical Explosive Bow   89.0    89.0        1.0
# 267  Legendary  Mechanical Explosive Bow   94.0    94.0        1.0
# 268     Common           Harvesting Tool   32.0    20.0        1.6
#
#      Magazine Size  Reload Time
# 0               30         2.52
# 1               30         2.41
# 2               30         2.30
# 3               30         2.18
# 4               30         2.07
# ..             ...          ...
# 264              1         1.00
# 265              1         1.00
# 266              1         1.00
# 267              1         1.00
# 268              0         0.00
#
# [269 rows x 7 columns]

# %% [markdown]
# ### Exploratory Analysis

# %%
fortnite.describe()
# Out:
#               DPS      Damage   Fire Rate  Magazine Size  Reload Time
# count  269.000000  269.000000  269.000000     269.000000   269.000000
# mean   132.063978   54.451301    4.396543      14.011152     2.988773
# std     63.608301   31.883389    4.338670      13.376713     1.503436
# min      0.000000    0.000000    0.000000       0.000000     0.000000
# 25%     75.000000   27.000000    1.000000       5.000000     2.100000
# 50%    132.000000   44.000000    3.750000       8.000000     2.520000
# 75%    179.400000   79.000000    6.750000      24.000000     3.600000
# max    319.580000  160.000000   20.000000     100.000000     9.240000

# %%
fortnite.shape
# Out:
# (269, 7)

# %%
fortnite.dtypes
# Out:
# Rarity            object
# Weapon            object
# DPS              float64
# Damage           float64
# Fire Rate        float64
# Magazine Size      int64
# Reload Time      float64
# dtype: object

# %%
fortnite.head()
# Out:
#       Rarity         Weapon    DPS  Damage  Fire Rate  Magazine Size  \
# 0     Common  Assault Rifle  165.0    30.0        5.5             30
# 1   Uncommon  Assault Rifle  170.5    31.0        5.5             30
# 2       Rare  Assault Rifle  181.5    33.0        5.5             30
# 3       Epic  Assault Rifle  192.5    35.0        5.5             30
# 4  Legendary  Assault Rifle  198.0    36.0        5.5             30
#
#    Reload Time
# 0         2.52
# 1         2.41
# 2         2.30
# 3         2.18
# 4         2.07

# %%
fortnite.tail()
# Out:
#         Rarity                    Weapon   DPS  Damage  Fire Rate  \
# 264       Epic  Mechanical Shockwave Bow  89.0    89.0        1.0
# 265  Legendary  Mechanical Shockwave Bow  94.0    94.0        1.0
# 266       Epic  Mechanical Explosive Bow  89.0    89.0        1.0
# 267  Legendary  Mechanical Explosive Bow  94.0    94.0        1.0
# 268     Common           Harvesting Tool  32.0    20.0        1.6
#
#      Magazine Size  Reload Time
# 264              1          1.0
# 265              1          1.0
# 266              1          1.0
# 267              1          1.0
# 268              0          0.0

# %%
fortnite.sample()
# Out:
#      Rarity             Weapon    DPS  Damage  Fire Rate  Magazine Size  \
# 119  Mythic  Evochrome Shotgun  294.0    98.0        1.5              8
#
#      Reload Time
# 119          4.8

# %%
fortnite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rarity         269 non-null    object
#  1   Weapon         269 non-null    object
#  2   DPS            269 non-null    float64
#  3   Damage         269 non-null    float64
#  4   Fire Rate      269 non-null    float64
#  5   Magazine Size  269 non-null    int64
#  6   Reload Time    269 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 14.8+ KB

# %%
fortnite.columns
# Out:
# Index(['Rarity', 'Weapon', 'DPS', 'Damage', 'Fire Rate', 'Magazine Size',
#        'Reload Time'],
#       dtype='object')

# %% [markdown]
# # Part 3: Cleaning

# %% [markdown]
# ## My exploratory analysis highlighted nothing that needs to be cleaned. There were no NaN values that need to filed in. If there were NaN values, I would compare the gun to similar types and enter a value that seemed logical with the rarity of the gun. The column names are all easy to understand and clearly display the values in the column.  I decided to not focus on the latest season because it just ended the other day and the conclusions I would come to don't matter anymore. A new season began with new weapons that are not in the data.

# %% [markdown]
# # Part 4: Answering Questions

# %% [markdown]
# ### Question 1: Which weapon has the quickest average reload time?

# %%
subset_reload = fortnite[["Rarity", "Weapon", "Reload Time"]]
subset_reload.tail()
# Out:
#         Rarity                    Weapon  Reload Time
# 264       Epic  Mechanical Shockwave Bow          1.0
# 265  Legendary  Mechanical Shockwave Bow          1.0
# 266       Epic  Mechanical Explosive Bow          1.0
# 267  Legendary  Mechanical Explosive Bow          1.0
# 268     Common           Harvesting Tool          0.0

# %%
subset_reload[subset_reload['Reload Time'] == subset_reload['Reload Time'].min()]
# Out:
#       Rarity           Weapon  Reload Time
# 235  Grenade              100          0.0
# 268   Common  Harvesting Tool          0.0

# %% [markdown]
# ### Question 2:   Is there a clear best gun in the game? (Largest magazine, quickest reload time, and quickest fire rate)

# %%
subset_best = fortnite[["Rarity", "Magazine Size", "Weapon", "Reload Time","Fire Rate" ]]
subset_best
# Out:
#         Rarity  Magazine Size                    Weapon  Reload Time  \
# 0       Common             30             Assault Rifle         2.52
# 1     Uncommon             30             Assault Rifle         2.41
# 2         Rare             30             Assault Rifle         2.30
# 3         Epic             30             Assault Rifle         2.18
# 4    Legendary             30             Assault Rifle         2.07
# ..         ...            ...                       ...          ...
# 264       Epic              1  Mechanical Shockwave Bow         1.00
# 265  Legendary              1  Mechanical Shockwave Bow         1.00
# 266       Epic              1  Mechanical Explosive Bow         1.00
# 267  Legendary              1  Mechanical Explosive Bow         1.00
# 268     Common              0           Harvesting Tool         0.00
#
#      Fire Rate
# 0          5.5
# 1          5.5
# 2          5.5
# 3          5.5
# 4          5.5
# ..         ...
# 264        1.0
# 265        1.0
# 266        1.0
# 267        1.0
# 268        1.6
#
# [269 rows x 5 columns]

# %%
subset_best[subset_best['Magazine Size'] == subset_best['Magazine Size'].max()]
# Out:
#     Rarity  Magazine Size             Weapon  Reload Time  Fire Rate
# 252   Rare            100  Light Machine Gun          5.0        8.0
# 253   Epic            100  Light Machine Gun          4.7        8.0

# %%
subset_best[subset_best['Fire Rate'] == subset_best['Fire Rate'].max()]
# Out:
#        Rarity  Magazine Size                Weapon  Reload Time  Fire Rate
# 40       Epic              2  Scoped Assault Rifle          2.2       20.0
# 41  Legendary              2  Scoped Assault Rifle          2.1       20.0

# %% [markdown]
# ###   Question 3: What is the average reload time of shotguns versus submachine guns?

# %%
subset_shot = fortnite.loc[fortnite.Weapon.str.contains('Shotgun')]
subset_shot
# Out:
#         Rarity                           Weapon     DPS  Damage  Fire Rate  \
# 61      Common                     Pump Shotgun   58.80    91.0       0.70
# 62    Uncommon                     Pump Shotgun   64.40    96.0       0.70
# 63        Rare                     Pump Shotgun   70.00   102.0       0.70
# 64        Epic                     Pump Shotgun   75.60   108.0       0.70
# 65   Legendary                     Pump Shotgun   81.20   114.0       0.70
# 66      Common                Makeshift Shotgun  110.00    88.0       1.25
# 67    Uncommon                Makeshift Shotgun  116.25    93.0       1.25
# 68        Rare                Makeshift Shotgun  122.50    98.0       1.25
# 69    Uncommon                   Primal Shotgun  216.60    57.0       3.80
# 70        Rare                   Primal Shotgun  228.00    60.0       3.80
# 71        Epic                   Primal Shotgun  239.40    63.0       3.80
# 72   Legendary                   Primal Shotgun  250.80    66.0       3.80
# 73      Mythic  Spire Assassin’s Primal Shotgun  262.20    69.0       3.90
# 74      Common                 Tactical Shotgun  108.00    72.0       1.50
# 75    Uncommon                 Tactical Shotgun  114.00    76.0       1.50
# 76        Rare                 Tactical Shotgun  120.00    80.0       1.50
# 77        Epic                 Tactical Shotgun  126.00    84.0       1.50
# 78   Legendary                 Tactical Shotgun  132.00    88.0       1.50
# 79      Common                   Charge Shotgun   71.40    84.0       0.85
# 80    Uncommon                   Charge Shotgun   74.80    88.0       0.85
# 81        Rare                   Charge Shotgun   79.05    93.0       0.85
# 82        Epic                   Charge Shotgun   83.30    98.0       0.85
# 83   Legendary                   Charge Shotgun   86.70   102.0       0.85
# 84      Common             Lever Action Shotgun   88.90    93.6       0.95
# 85    Uncommon             Lever Action Shotgun   93.20    98.1       0.95
# 86        Rare             Lever Action Shotgun   98.30   103.5       0.95
# 87        Epic             Lever Action Shotgun  103.50   108.9       0.95
# 88   Legendary             Lever Action Shotgun  108.60   114.3       0.95
# 89        Epic          Dragon’s Breath Shotgun  152.00   152.0       1.00
# 90   Legendary          Dragon’s Breath Shotgun  160.00   160.0       1.00
# 91        Rare                    Heavy Shotgun   70.00    70.0       1.00
# 92        Epic                    Heavy Shotgun   74.00    74.0       1.00
# 93   Legendary                    Heavy Shotgun   77.00    77.0       1.00
# 94      Common                     Drum Shotgun  180.00    45.0       4.00
# 95    Uncommon                     Drum Shotgun  192.00    48.0       4.00
# 96        Rare                     Drum Shotgun  200.00    50.0       4.00
# 97        Rare                   Combat Shotgun   96.90    57.0       1.70
# 98        Epic                   Combat Shotgun  102.00    60.0       1.70
# 99   Legendary                   Combat Shotgun  107.10    63.0       1.70
# 100       Epic            Double Barrel Shotgun  216.60   114.0       1.90
# 101  Legendary            Double Barrel Shotgun  228.00   120.0       1.90
# 103     Common                 Two-Shot Shotgun   45.90    54.0       0.85
# 104   Uncommon                 Two-Shot Shotgun   48.45    57.0       0.85
# 105       Rare                 Two-Shot Shotgun   51.00    60.0       0.85
# 106       Epic                 Two-Shot Shotgun   53.55    63.0       0.85
# 107  Legendary                 Two-Shot Shotgun   56.10    66.0       0.85
# 108     Mythic                 Two-Shot Shotgun  102.81    69.0       1.49
# 109     Common                    Prime Shotgun   79.00    76.0       1.05
# 110   Uncommon                    Prime Shotgun   83.00    79.0       1.05
# 111       Rare                    Prime Shotgun   88.00    84.0       1.05
# 112       Epic                    Prime Shotgun   93.00    88.0       1.05
# 113  Legendary                    Prime Shotgun   96.00    92.0       1.05
# 114     Mythic                    Prime Shotgun  101.00    96.0       1.05
# 115   Uncommon                Evochrome Shotgun  121.50    81.0       1.50
# 116       Rare                Evochrome Shotgun  127.50    85.0       1.50
# 117       Epic                Evochrome Shotgun  133.50    89.0       1.50
# 118  Legendary                Evochrome Shotgun  141.00    94.0       1.50
# 119     Mythic                Evochrome Shotgun  294.00    98.0       1.50
#
#      Magazine Size  Reload Time
# 61               5         5.10
# 62               5         4.75
# 63               5         4.40
# 64               5         4.05
# 65               5         3.70
# 66               2         3.50
# 67               2         3.00
# 68               2         2.50
# 69              12         3.90
# 70              12         3.80
# 71              12         3.60
# 72              12         3.40
# 73              12         3.20
# 74               8         6.27
# 75               8         5.99
# 76               8         5.70
# 77               8         5.41
# 78               8         5.13
# 79               4         4.70
# 80               4         4.50
# 81               4         4.30
# 82               5         4.10
# 83               5         3.90
# 84               6         6.60
# 85               6         6.30
# 86               6         6.00
# 87               6         5.70
# 88               6         5.40
# 89               4         4.30
# 90               4         4.10
# 91               7         4.30
# 92               7         5.90
# 93               7         5.60
# 94              12         4.70
# 95              12         4.50
# 96              12         4.30
# 97               8         5.30
# 98               8         5.00
# 99               8         4.70
# 100              2         2.80
# 101              2         2.70
# 103              8         9.24
# 104              8         8.82
# 105              8         8.40
# 106              8         7.98
# 107              8         7.56
# 108              8         7.14
# 109              4         4.50
# 110              4         4.50
# 111              4         4.50
# 112              4         4.50
# 113              4         4.50
# 114              4         4.50
# 115              8         5.99
# 116              8         5.70
# 117              8         5.40
# 118              8         5.10
# 119              8         4.80

# %%
subset_shot['Reload Time'].mean()
# Out:
# 5.0039655172413795

# %%
subset_sub = fortnite.loc[fortnite.Weapon.str.contains('Submachine')]
subset_sub
# Out:
#         Rarity                     Weapon    DPS  Damage  Fire Rate  \
# 120     Common             Submachine Gun  160.0    16.0       10.0
# 121   Uncommon             Submachine Gun  170.0    17.0       10.0
# 122       Rare             Submachine Gun  180.0    18.0       10.0
# 123       Epic             Submachine Gun  190.0    19.0       10.0
# 124  Legendary             Submachine Gun  200.0    20.0       10.0
# 134     Common  Suppressed Submachine Gun  156.0    20.0        7.8
# 135   Uncommon  Suppressed Submachine Gun  163.8    21.0        7.8
# 136       Rare  Suppressed Submachine Gun  171.6    22.0        7.8
# 137       Epic  Suppressed Submachine Gun  179.4    23.0        7.8
# 138  Legendary  Suppressed Submachine Gun  187.2    24.0        7.8
# 150   Uncommon    Tactical Submachine Gun  162.0    18.0        9.0
# 151       Rare    Tactical Submachine Gun  171.0    19.0        9.0
# 152       Epic    Tactical Submachine Gun  180.0    20.0        9.0
# 153  Legendary    Tactical Submachine Gun  189.0    21.0        9.0
#
#      Magazine Size  Reload Time
# 120             30         2.31
# 121             30         2.20
# 122             30         2.10
# 123             35         2.00
# 124             35         1.89
# 134             30         2.10
# 135             30         2.10
# 136             30         2.00
# 137             30         1.90
# 138             30         1.80
# 150             25         2.20
# 151             25         2.10
# 152             25         2.00
# 153             25         1.90

# %%
subset_sub['Reload Time'].mean()
# Out:
# 2.0428571428571427

# %% [markdown]
# ### Question 4:     Overall which Assault Rifle deals the most damage per magazine(damage*magazine)?

# %%
subset_assault = fortnite.loc[fortnite.Weapon.str.contains('Assault')]
subset_assault
# Out:
#        Rarity                        Weapon     DPS  Damage  Fire Rate  \
# 0      Common                 Assault Rifle  165.00    30.0       5.50
# 1    Uncommon                 Assault Rifle  170.50    31.0       5.50
# 2        Rare                 Assault Rifle  181.50    33.0       5.50
# 3        Epic                 Assault Rifle  192.50    35.0       5.50
# 4   Legendary                 Assault Rifle  198.00    36.0       5.50
# 12     Mythic          Skye’s Assault Rifle  222.00    37.0       6.00
# 13     Common           Heavy Assault Rifle  140.25    33.0       4.25
# 14   Uncommon           Heavy Assault Rifle  148.75    35.0       4.25
# 15       Rare           Heavy Assault Rifle  157.25    37.0       4.25
# 16       Epic           Heavy Assault Rifle  165.75    42.0       4.25
# 17  Legendary           Heavy Assault Rifle  174.25    41.0       4.25
# 19     Common           Burst Assault Rifle  122.45    31.0       3.95
# 20   Uncommon           Burst Assault Rifle  126.40    32.0       3.95
# 21       Rare           Burst Assault Rifle  134.30    34.0       3.95
# 22       Epic           Burst Assault Rifle  142.20    36.0       3.95
# 23  Legendary           Burst Assault Rifle  146.15    37.0       3.95
# 24     Mythic   Ocean’s Burst Assault Rifle  154.05    39.0       3.95
# 30       Rare      Suppressed Assault Rifle  165.00    30.0       5.50
# 31       Epic      Suppressed Assault Rifle  176.00    32.0       5.50
# 32  Legendary      Suppressed Assault Rifle  181.50    33.0       5.50
# 33       Rare        Tactical Assault Rifle  154.00    22.0       7.00
# 34       Epic        Tactical Assault Rifle  161.00    23.0       7.00
# 35  Legendary        Tactical Assault Rifle  168.00    24.0       7.00
# 36       Epic  Thermal Scoped Assault Rifle   64.80    36.0      15.00
# 37  Legendary  Thermal Scoped Assault Rifle   66.60    37.0      15.00
# 38   Uncommon          Scoped Assault Rifle   64.00    32.0      15.00
# 39       Rare          Scoped Assault Rifle   68.00    34.0      15.00
# 40       Epic          Scoped Assault Rifle   72.00    36.0      20.00
# 41  Legendary          Scoped Assault Rifle   74.00    37.0      20.00
# 50     Common          Hammer Assault Rifle  156.60    27.0       5.80
# 51   Uncommon          Hammer Assault Rifle  168.20    29.0       5.80
# 52       Rare          Hammer Assault Rifle  174.00    30.0       5.80
# 53       Epic          Hammer Assault Rifle  185.60    32.0       5.80
# 54  Legendary          Hammer Assault Rifle  191.40    33.0       5.80
# 55     Mythic          Hammer Assault Rifle  203.00    35.0       5.80
#
#     Magazine Size  Reload Time
# 0              30         2.52
# 1              30         2.41
# 2              30         2.30
# 3              30         2.18
# 4              30         2.07
# 12             30         2.00
# 13             25         3.08
# 14             25         2.94
# 15             25         2.80
# 16             25         2.66
# 17             25         2.52
# 19             20         2.86
# 20             20         2.73
# 21             20         2.60
# 22             20         2.47
# 23             20         2.34
# 24             20         2.20
# 30             30         2.30
# 31             30         2.20
# 32             30         2.10
# 33             30         2.20
# 34             30         2.10
# 35             30         2.00
# 36              2         2.20
# 37              2         2.10
# 38              2         2.40
# 39              2         2.30
# 40              2         2.20
# 41              2         2.10
# 50             20         2.42
# 51             20         2.31
# 52             20         2.20
# 53             20         2.09
# 54             20         1.98
# 55             20         1.87

# %%
subset_assault2 = subset_assault[["Rarity", "Weapon", "Damage", "Magazine Size" ]]
subset_assault2
# Out:
#        Rarity                        Weapon  Damage  Magazine Size
# 0      Common                 Assault Rifle    30.0             30
# 1    Uncommon                 Assault Rifle    31.0             30
# 2        Rare                 Assault Rifle    33.0             30
# 3        Epic                 Assault Rifle    35.0             30
# 4   Legendary                 Assault Rifle    36.0             30
# 12     Mythic          Skye’s Assault Rifle    37.0             30
# 13     Common           Heavy Assault Rifle    33.0             25
# 14   Uncommon           Heavy Assault Rifle    35.0             25
# 15       Rare           Heavy Assault Rifle    37.0             25
# 16       Epic           Heavy Assault Rifle    42.0             25
# 17  Legendary           Heavy Assault Rifle    41.0             25
# 19     Common           Burst Assault Rifle    31.0             20
# 20   Uncommon           Burst Assault Rifle    32.0             20
# 21       Rare           Burst Assault Rifle    34.0             20
# 22       Epic           Burst Assault Rifle    36.0             20
# 23  Legendary           Burst Assault Rifle    37.0             20
# 24     Mythic   Ocean’s Burst Assault Rifle    39.0             20
# 30       Rare      Suppressed Assault Rifle    30.0             30
# 31       Epic      Suppressed Assault Rifle    32.0             30
# 32  Legendary      Suppressed Assault Rifle    33.0             30
# 33       Rare        Tactical Assault Rifle    22.0             30
# 34       Epic        Tactical Assault Rifle    23.0             30
# 35  Legendary        Tactical Assault Rifle    24.0             30
# 36       Epic  Thermal Scoped Assault Rifle    36.0              2
# 37  Legendary  Thermal Scoped Assault Rifle    37.0              2
# 38   Uncommon          Scoped Assault Rifle    32.0              2
# 39       Rare          Scoped Assault Rifle    34.0              2
# 40       Epic          Scoped Assault Rifle    36.0              2
# 41  Legendary          Scoped Assault Rifle    37.0              2
# 50     Common          Hammer Assault Rifle    27.0             20
# 51   Uncommon          Hammer Assault Rifle    29.0             20
# 52       Rare          Hammer Assault Rifle    30.0             20
# 53       Epic          Hammer Assault Rifle    32.0             20
# 54  Legendary          Hammer Assault Rifle    33.0             20
# 55     Mythic          Hammer Assault Rifle    35.0             20

# %%
subset_assault2.columns = ['Rarity', 'Weapon', 'Damage', 'MagazineSize']
subset_assault2
# Out:
#        Rarity                        Weapon  Damage  MagazineSize
# 0      Common                 Assault Rifle    30.0            30
# 1    Uncommon                 Assault Rifle    31.0            30
# 2        Rare                 Assault Rifle    33.0            30
# 3        Epic                 Assault Rifle    35.0            30
# 4   Legendary                 Assault Rifle    36.0            30
# 12     Mythic          Skye’s Assault Rifle    37.0            30
# 13     Common           Heavy Assault Rifle    33.0            25
# 14   Uncommon           Heavy Assault Rifle    35.0            25
# 15       Rare           Heavy Assault Rifle    37.0            25
# 16       Epic           Heavy Assault Rifle    42.0            25
# 17  Legendary           Heavy Assault Rifle    41.0            25
# 19     Common           Burst Assault Rifle    31.0            20
# 20   Uncommon           Burst Assault Rifle    32.0            20
# 21       Rare           Burst Assault Rifle    34.0            20
# 22       Epic           Burst Assault Rifle    36.0            20
# 23  Legendary           Burst Assault Rifle    37.0            20
# 24     Mythic   Ocean’s Burst Assault Rifle    39.0            20
# 30       Rare      Suppressed Assault Rifle    30.0            30
# 31       Epic      Suppressed Assault Rifle    32.0            30
# 32  Legendary      Suppressed Assault Rifle    33.0            30
# 33       Rare        Tactical Assault Rifle    22.0            30
# 34       Epic        Tactical Assault Rifle    23.0            30
# 35  Legendary        Tactical Assault Rifle    24.0            30
# 36       Epic  Thermal Scoped Assault Rifle    36.0             2
# 37  Legendary  Thermal Scoped Assault Rifle    37.0             2
# 38   Uncommon          Scoped Assault Rifle    32.0             2
# 39       Rare          Scoped Assault Rifle    34.0             2
# 40       Epic          Scoped Assault Rifle    36.0             2
# 41  Legendary          Scoped Assault Rifle    37.0             2
# 50     Common          Hammer Assault Rifle    27.0            20
# 51   Uncommon          Hammer Assault Rifle    29.0            20
# 52       Rare          Hammer Assault Rifle    30.0            20
# 53       Epic          Hammer Assault Rifle    32.0            20
# 54  Legendary          Hammer Assault Rifle    33.0            20
# 55     Mythic          Hammer Assault Rifle    35.0            20

# %%
damagepermag = []
damagepermag = subset_assault2.Damage * subset_assault2.MagazineSize
damagepermag
# Out:
# 0      900.0
# 1      930.0
# 2      990.0
# 3     1050.0
# 4     1080.0
# 12    1110.0
# 13     825.0
# 14     875.0
# 15     925.0
# 16    1050.0
# 17    1025.0
# 19     620.0
# 20     640.0
# 21     680.0
# 22     720.0
# 23     740.0
# 24     780.0
# 30     900.0
# 31     960.0
# 32     990.0
# 33     660.0
# 34     690.0
# 35     720.0
# 36      72.0
# 37      74.0
# 38      64.0
# 39      68.0
# 40      72.0
# 41      74.0
# 50     540.0
# 51     580.0
# 52     600.0
# 53     640.0
# 54     660.0
# 55     700.0
# dtype: float64

# %% [markdown]
# ### Question 5:     Is the suppressed submachine gun or rapid fire submachine better to use?

# %%
subset_rapid = fortnite.loc[fortnite.Weapon.str.contains('Rapid')]
subset_rapid
# Out:
#         Rarity          Weapon    DPS  Damage  Fire Rate  Magazine Size  \
# 139     Common  Rapid Fire SMG  195.0    13.0       15.0             20
# 140   Uncommon  Rapid Fire SMG  210.0    14.0       15.0             20
# 141       Rare  Rapid Fire SMG  225.0    15.0       15.0             20
# 142       Epic  Rapid Fire SMG  240.0    16.0       15.0             26
# 143  Legendary  Rapid Fire SMG  255.0    17.0       15.0             26
#
#      Reload Time
# 139         1.65
# 140         1.58
# 141         1.50
# 142         1.42
# 143         1.32

# %%
subset_rapid2 = subset_rapid[["Weapon","DPS"]]
subset_rapid2
# Out:
#              Weapon    DPS
# 139  Rapid Fire SMG  195.0
# 140  Rapid Fire SMG  210.0
# 141  Rapid Fire SMG  225.0
# 142  Rapid Fire SMG  240.0
# 143  Rapid Fire SMG  255.0

# %%
subset_rapid2['DPS'].mean()
# Out:
# 225.0

# %%
subset_sup = fortnite.loc[fortnite.Weapon.str.contains('Suppressed Sub')]
subset_sup
# Out:
#         Rarity                     Weapon    DPS  Damage  Fire Rate  \
# 134     Common  Suppressed Submachine Gun  156.0    20.0        7.8
# 135   Uncommon  Suppressed Submachine Gun  163.8    21.0        7.8
# 136       Rare  Suppressed Submachine Gun  171.6    22.0        7.8
# 137       Epic  Suppressed Submachine Gun  179.4    23.0        7.8
# 138  Legendary  Suppressed Submachine Gun  187.2    24.0        7.8
#
#      Magazine Size  Reload Time
# 134             30          2.1
# 135             30          2.1
# 136             30          2.0
# 137             30          1.9
# 138             30          1.8

# %%
subset_sup2 = subset_sup[["Weapon","DPS"]]
subset_sup2
# Out:
#                         Weapon    DPS
# 134  Suppressed Submachine Gun  156.0
# 135  Suppressed Submachine Gun  163.8
# 136  Suppressed Submachine Gun  171.6
# 137  Suppressed Submachine Gun  179.4
# 138  Suppressed Submachine Gun  187.2

# %%
subset_sup2['DPS'].mean()
# Out:
# 171.6
